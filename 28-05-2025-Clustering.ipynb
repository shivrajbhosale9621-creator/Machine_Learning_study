# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
 data=pd.read_csv(r"C:\Data Sets\Mall_Customers.csv")
data.shape
# Out:
# (200, 5)

# %%
data.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
anual_income=data['Annual Income (k$)']
spending_score=data['Spending Score (1-100)']

# %%
#selecting the columns method
#m-1:Select by using column names
#M-2: Select by using iloc
#M-3: by droping unwanted columns
x=data.iloc[:,[3,4]].values

# %% [markdown]
# ## Scatter plot

# %%
data.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
plt.scatter(data['Annual Income (k$)'],data['Spending Score (1-100)'])

# %%
from sklearn.cluster import KMeans

# %%
### Just applying one cluster
### Base Model

# %%
kmeans_1=KMeans(n_clusters=1,max_iter=300,random_state=1234)
kmeans_1
# Out:
# KMeans(n_clusters=1, random_state=1234)

# %%
x=data.iloc[:,[3,4]]

# %%
kmeans_1.fit(x)
# Out:
# KMeans(n_clusters=1, random_state=1234)

# %%
from sklearn.cluster import KMeans
kmeans_1=KMeans(n_clusters=1,max_iter=300,random_state=1234)
kmeans_1.fit(x)
#we are not interested which data point
#belongs tow which cluster
#bcz here only one cluster
# Out:
# KMeans(n_clusters=1, random_state=1234)

# %%
kmeans_1.inertia_# varaince
# Out:
# 269981.28

# %%
means=kmeans_1.cluster_centers_
means
# Out:
# array([[60.56, 50.2 ]])

# %%
data['Annual Income (k$)'].mean(),data['Spending Score (1-100)'].mean()
# Out:
# (60.56, 50.2)

# %%
wss=[]
for i in range(1,20):
    kmean=KMeans(n_clusters=i,max_iter=300,random_state=1234)
    kmean.fit(x)
    wss.append(round(kmean.inertia_,2))

# %%
wss

# If you are increase more cluster
#data points will be divided across the clusters
# Out:
# [269981.28,
#  185140.02,
#  106348.37,
#  73880.64,
#  44448.46,
#  37233.81,
#  30241.34,
#  29474.65,
#  23977.39,
#  20792.48,
#  19295.24,
#  16171.41,
#  14749.86,
#  13905.26,
#  12413.87,
#  10929.42,
#  10069.84,
#  9603.0,
#  9287.58]

# %%
plt.scatter(range(1,21),wss )
plt.plot(range(1,21),wss)
plt.title("The Elbow method")
plt.xlabel('Clusters')
plt.ylabel('WSS')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 plt.scatter(range(1,21),wss)
#       2 plt.plot(range(1,21),wss)
#       3 plt.title("The Elbow method")
#
# File C:\anaconda\Lib\site-packages\matplotlib\pyplot.py:3903, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3884 @_copy_docstring_and_deprecators(Axes.scatter)
#    3885 def scatter(
#    3886     x: float | ArrayLike,
#    (...)
#    3901     **kwargs,
#    3902 ) -> PathCollection:
# -> 3903     __ret = gca().scatter(
#    3904         x,
#    3905         y,
#    3906         s=s,
#    3907         c=c,
#    3908         marker=marker,
#    3909         cmap=cmap,
#    3910         norm=norm,
#    3911         vmin=vmin,
#    3912         vmax=vmax,
#    3913         alpha=alpha,
#    3914         linewidths=linewidths,
#    3915         edgecolors=edgecolors,
#    3916         plotnonfinite=plotnonfinite,
#    3917         **({"data": data} if data is not None else {}),
#    3918         **kwargs,
#    3919     )
#    3920     sci(__ret)
#    3921     return __ret
#
# File C:\anaconda\Lib\site-packages\matplotlib\__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File C:\anaconda\Lib\site-packages\matplotlib\axes\_axes.py:4787, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4785 y = np.ma.ravel(y)
#    4786 if x.size != y.size:
# -> 4787     raise ValueError("x and y must be the same size")
#    4789 if s is None:
#    4790     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4791          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size
